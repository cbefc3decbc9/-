# %% [markdown]
# 导入包

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# 读取文件
# 一共九个城市
# asti, bologna, cesena, faenza, ferrara, mantova, milano, piacenza, ravenna, torino

# %%
# 将DataFrame对象，以csv文件形式保存起来
asti.to_csv(filenam)

# %%
asti1 = pd.read_csv('asti_150715.csv')
asti2 = pd.read_csv('asti_250715.csv')
asti3 = pd.read_csv('asti_270615.csv')
asti = pd.concat([asti1,asti2,asti3], ignore_index=True)

# %%
bologna1 = pd.read_csv('bologna_150715.csv')
bologna2 = pd.read_csv('bologna_270615.csv')
bologna3 = pd.read_csv('bologna_250715.csv')
bologna = pd.concat([bologna1,bologna2,bologna3], ignore_index=True)

# %%
cesena1 = pd.read_csv('./cesena_150715.csv')
cesena2 = pd.read_csv('./cesena_250715.csv')
cesena3 = pd.read_csv('./cesena_270615.csv')
cesena = pd.concat([cesena1,cesena2,cesena3],ignore_index=True)

# %%
ferrara1 = pd.read_csv('./ferrara_150715.csv')
ferrara2 = pd.read_csv('./ferrara_250715.csv')
ferrara3 = pd.read_csv('./ferrara_270615.csv')
ferrara = pd.concat([ferrara1,ferrara2,ferrara3],ignore_index=True)

# %%
faenza1 = pd.read_csv('./faenza_150715.csv')
faenza2 = pd.read_csv('./faenza_250715.csv')
faenza3 = pd.read_csv('./faenza_270615.csv')
faenza = pd.concat([faenza1,faenza2,faenza3],ignore_index=True)

# %%
mantova1 = pd.read_csv('./mantova_150715.csv')
mantova2 = pd.read_csv('./mantova_250715.csv')
mantova3 = pd.read_csv('./mantova_270615.csv')
mantova = pd.concat([mantova1,mantova2,mantova3],ignore_index=True)

# %%
milano1 = pd.read_csv('./milano_150715.csv')
milano2 = pd.read_csv('./milano_250715.csv')
milano3 = pd.read_csv('./milano_270615.csv')
milano = pd.concat([milano1,milano2,milano3],ignore_index=True)

# %%
piacenza1 = pd.read_csv('./piacenza_150715.csv')
piacenza2 = pd.read_csv('./piacenza_250715.csv')
piacenza3 = pd.read_csv('./piacenza_270615.csv')
piacenza = pd.concat([piacenza1,piacenza2,piacenza3],ignore_index=True)

# %%
ravenna1 = pd.read_csv('./ravenna_150715.csv')
ravenna2 = pd.read_csv('./ravenna_250715.csv')
ravenna3 = pd.read_csv('./ravenna_270615.csv')
ravenna = pd.concat([ravenna1,ravenna2,ravenna3],ignore_index=True)

# %%
torino1 = pd.read_csv('./torino_150715.csv')
torino2 = pd.read_csv('./torino_250715.csv')
torino3 = pd.read_csv('./torino_270615.csv')
torino = pd.concat([torino1,torino2,torino3],ignore_index=True)
torino
# Out:
#     Unnamed: 0   temp  humidity  pressure       description          dt  \
# 0            0  28.34        65      1017      Sky is Clear  1436863109
# 1            1  29.25        65      1017      Sky is Clear  1436866696
# 2            2  30.40        58      1017      Sky is Clear  1436870399
# 3            3  31.37        54      1017      Sky is Clear  1436874005
# 4            4  32.59        45      1016        few clouds  1436877558
# 5            5  33.64        46      1016        few clouds  1436881216
# 6            6  34.03        46      1015        few clouds  1436884810
# 7            7  33.94        49      1015        few clouds  1436888411
# 8            8  34.69        46      1015        few clouds  1436892015
# 9            9  33.25        46      1014      Sky is Clear  1436895603
# 10          10  30.96        58      1014      Sky is Clear  1436899245
# 11          11  29.14        62      1015      Sky is Clear  1436902826
# 12          12  27.73        69      1015      Sky is Clear  1436906416
# 13          13  26.66        69      1016      Sky is Clear  1436910029
# 14          14  25.78        69      1016      Sky is Clear  1436913632
# 15          15  25.11        73      1016      Sky is Clear  1436917196
# 16          16  24.91        73      1016      Sky is Clear  1436920815
# 17          17  24.84        73      1016      Sky is Clear  1436924359
# 18          18  24.00        73      1016      Sky is Clear  1436927985
# 19          19  23.00        83      1017     broken clouds  1436931604
# 20          20  23.00        78      1017  scattered clouds  1436935183
# 21          21  25.00        73      1017        few clouds  1436938777
# 22          22  27.00        65      1017        few clouds  1436942396
# 23          23  27.00        65      1017      Sky is Clear  1436945890
# 24           0  30.29        54      1012      Sky is Clear  1437730770
# 25           1  30.68        58      1012      Sky is Clear  1437734413
# 26           2  30.96        58      1012        few clouds  1437737966
# 27           3  30.91        51      1011        few clouds  1437741497
# 28           4  32.20        51      1011        few clouds  1437745130
# 29           5  30.16        48      1009     moderate rain  1437748723
# ..         ...    ...       ...       ...               ...         ...
# 38          14  21.75        64      1009     broken clouds  1437781191
# 39          15  23.01        64      1009      Sky is Clear  1437784762
# 40          16  22.39        64      1009        light rain  1437788332
# 41          17  21.50        73      1009  scattered clouds  1437791949
# 42          18  21.84        83      1009  scattered clouds  1437795572
# 43          19  21.84        77      1009     broken clouds  1437799177
# 44          20  21.50        88      1010     broken clouds  1437802719
# 45          21  23.54        78      1010      Sky is Clear  1437806353
# 46          22  25.72        64      1010      Sky is Clear  1437809920
# 47          23  25.84        64      1010      Sky is Clear  1437813560
# 48           0  23.80        64      1019      Sky is Clear  1435387651
# 49           1  24.68        60      1018      Sky is Clear  1435390804
# 50           2  25.12        60      1018      Sky is Clear  1435394206
# 51           3  25.54        60      1018      Sky is Clear  1435398681
# 52           4  27.42        57      1017      Sky is Clear  1435402112
# 53           5  28.97        47      1017      Sky is Clear  1435405743
# 54           6  29.36        45      1017      Sky is Clear  1435409402
# 55           7  30.56        45      1015      Sky is Clear  1435416605
# 56           8  31.04        48      1015      Sky is Clear  1435420220
# 57           9  31.32        48      1014      Sky is Clear  1435423957
# 58          10  30.69        48      1014      Sky is Clear  1435427586
# 59          11  25.15        73      1015      Sky is Clear  1435438091
# 60          12  24.57        73      1016      Sky is Clear  1435441890
# 61          13  24.00        73      1016      Sky is Clear  1435445529
# 62          14  22.19        77      1017     broken clouds  1435452880
# 63          15  20.50        77      1017     broken clouds  1435456195
# 64          16  18.94        77      1018        few clouds  1435459725
# 65          17  19.07        77      1018      Sky is Clear  1435463493
# 66          18  19.05        82      1018      Sky is Clear  1435466876
# 67          19  21.20        82      1018      Sky is Clear  1435470573
#
#     wind_speed  wind_deg    city                  day  dist
# 0          3.1        20  Torino  2015-07-14 10:38:29   357
# 60         3.1       340  Torino  2015-06-27 23:51:30   357
# 61         3.1       340  Torino  2015-06-28 00:52:09   357
# 62         2.1       340  Torino  2015-06-28 02:54:40   357
# 63         2.1       340  Torino  2015-06-28 03:49:55   357
# 64         2.6        30  Torino  2015-06-28 04:48:45   357
# 65         2.1       360  Torino  2015-06-28 05:51:33   357
# 66         1.5        10  Torino  2015-06-28 06:47:56   357
# 67         1.0        40  Torino  2015-06-28 07:49:33   357
#
# [68 rows x 11 columns]

# %% [markdown]
# 查看行数

# %%
print(ravenna.shape)
print(torino.shape)
# Out:
# (66, 11)
# (68, 11)

# %% [markdown]
# 去除多余的列：Unnamed: 0

# %%
cities = [torino,asti,bologna,cesena,ferrara,
          mantova,milano,piacenza,ravenna,faenza]

# %%
for c in cities:
    c.drop('Unnamed: 0', axis = 1, inplace=True)

# %%
asti.head()
# Out:
#     temp  humidity  pressure   description          dt  wind_speed  wind_deg  \
# 0  28.05        66      1014  Sky is Clear  1436863176        2.57    42.501
# 1  29.51        64      1014  Sky is Clear  1436866759        1.54   263.000
# 2  30.39        58      1017  Sky is Clear  1436870510        2.60   100.000
# 3  31.10        54      1017  Sky is Clear  1436874098        2.10    90.000
# 4  33.23        45      1016    few clouds  1436877645        2.10   120.000
#
#    city                  day  dist
# 0  Asti  2015-07-14 10:39:36   315
# 1  Asti  2015-07-14 11:39:19   315
# 2  Asti  2015-07-14 12:41:50   315
# 3  Asti  2015-07-14 13:41:38   315
# 4  Asti  2015-07-14 14:40:45   315

# %%
# 写十次
torino.drop('Unnamed: 0', axis = 1, inplace=True)

# %% [markdown]
# 获取每个城市距离海边距离，最高温度，最低温度，最高湿度，最低湿度

# %%
# 各城市与海边的距离
dists = []
temp_max = []
temp_min = []
hum_max = []
hum_min = []

for city in cities:
    dists.append(city['dist'][0])
    temp_max.append(city['temp'].max())
    temp_min.append(city['temp'].min())
    hum_max.append(city['humidity'].max())
    hum_min.append(city['humidity'].min())

# %%
temp_max
# Out:
# [34.689999999999998,
#  34.310000000000002,
#  33.850000000000016,
#  32.810000000000002,
#  33.430000000000007,
#  34.180000000000007,
#  34.810000000000002,
#  33.920000000000016,
#  32.79000000000002,
#  32.740000000000009]

# %% [markdown]
# 显示最高温度离海远近的关系

# %%
plt.scatter(dists, temp_max)

# %% [markdown]
# 观察发现，离海近的可以形成一条直线，离海远的也能形成一条直线。
# 首先使用numpy：把列表转换为numpy数组，用于后续计算。
# 分别以100公里和50公里为分界点，划分为离海近和离海远的两组数据

# %%
x = np.array(dists)
y = np.array(temp_max)

# %%
# x1表示小于100公里的数据
x1 = x[x < 100].reshape((5,1))
# y1表示小于100公里城市的最高温度
y1 = y[x < 100].reshape((5,1))

x2 = x[x > 50].reshape((6,1))
y2 = y[x > 50].reshape((6,1))

# %% [markdown]
# 使用支持向量机计算回归参数

# %%
# 机器学习的模型
from sklearn.svm import SVR

# 创建算法
svr1 = SVR(kernel='linear')
svr2 = SVR(kernel='linear')

# 将数据交给算法fit == feed(喂)
# 里面的数据必须是二维的
# 训练数据
svr1.fit(x1,y1)
svr2.fit(x2,y2)

# 预测数据
x_test1 = np.linspace(0,100,20).reshape((20,1))
x_test2 = np.linspace(50,350,20).reshape((20,1))

print(x_test1.shape,x_test2.shape)
# Out:
# (20, 1) (20, 1)
# /usr/local/lib/python3.5/dist-packages/sklearn/utils/validation.py:526: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# y1_ 表示得到的预测的数据
# .predict是预测方法
y1_ = svr1.predict(x_test1)
y2_ = svr2.predict(x_test2)
print(y1_, y2_)
# Out:
# [ 32.55539683  32.64395155  32.73250627  32.82106099  32.90961571
#   32.99817043  33.08672515  33.17527987  33.26383459  33.35238931
#   33.44094403  33.52949875  33.61805347  33.70660819  33.79516291
#   33.88371763  33.97227235  34.06082707  34.14938179  34.23793651] [ 33.90300699  33.93834008  33.97367317  34.00900626  34.04433934
#   34.07967243  34.11500552  34.15033861  34.1856717   34.22100478
#   34.25633787  34.29167096  34.32700405  34.36233714  34.39767022
#   34.43300331  34.4683364   34.50366949  34.53900258  34.57433566]

# %%
plt.scatter(dists,temp_max)

plt.plot(x_test1, y1_, 'r')
plt.plot(x_test2, y2_, 'b')

# %% [markdown]
# 查看最低温度与海洋距离的关系

# %%
plt.scatter(dists, temp_min)

# %% [markdown]
# 最低湿度与海洋距离的关系

# %%
plt.scatter(dists, hum_min)

# %% [markdown]
# 最高湿度与海洋距离的关系

# %%
plt.scatter(dists, hum_max)

# %% [markdown]
# 平均湿度与海洋距离的关系

# %%
hum_mean = []
for city in cities:
    hum_mean.append(city['humidity'].mean())
hum_mean
# Out:
# [63.191176470588232,
#  63.132352941176471,
#  61.338235294117645,
#  77.647058823529406,
#  61.308823529411768,
#  59.147058823529413,
#  56.984848484848484,
#  59.308823529411768,
#  68.015151515151516,
#  81.074626865671647]

# %%
plt.scatter(dists, hum_mean)

# %% [markdown]
# 风向与风速的关系

# %%
milano
# Out:
#      temp  humidity  pressure             description          dt  wind_speed  \
# 0   28.57        54      1016            Sky is Clear  1436863175         2.1
# 1   29.74        48      1016            Sky is Clear  1436866758         2.6
# 2   31.12        48      1016            Sky is Clear  1436870509         2.6
# 3   32.16        45      1015            Sky is Clear  1436874098         2.1
# 4   33.59        43      1015            Sky is Clear  1436877644         3.1
# 5   34.21        36      1014            Sky is Clear  1436881329         2.1
# 6   34.41        38      1014            Sky is Clear  1436884928         2.1
# 7   34.81        38      1014            Sky is Clear  1436888512         3.1
# 8   34.09        38      1013            Sky is Clear  1436892131         2.6
# 9   33.20        35      1014            Sky is Clear  1436895722         4.1
# 10  31.55        48      1013            Sky is Clear  1436899336         2.1
# 11  28.33        61      1014            Sky is Clear  1436902942         2.1
# 12  27.58        51      1014            Sky is Clear  1436906530         2.1
# 13  26.29        61      1015        scattered clouds  1436910148         0.5
# 14  25.32        61      1015              few clouds  1436913738         1.0
# 15  24.23        65      1015            Sky is Clear  1436917310         1.5
# 16  24.29        65      1015            Sky is Clear  1436920930         1.5
# 17  23.75        65      1016            Sky is Clear  1436924426         2.6
# 18  23.64        69      1015            Sky is Clear  1436928077         1.0
# 11       200  Milano  2015-07-14 21:42:22   250
# 12       200  Milano  2015-07-14 22:42:10   250
# 13         0  Milano  2015-07-14 23:42:28   250
# 14         0  Milano  2015-07-15 00:42:18   250
# 15        70  Milano  2015-07-15 01:41:50   250
# 16        80  Milano  2015-07-15 02:42:10   250
# 17        80  Milano  2015-07-15 03:40:26   250
# 18         0  Milano  2015-07-15 04:41:17   250
# 19        90  Milano  2015-07-15 05:41:57   250
# 20       140  Milano  2015-07-15 06:41:37   250
# 21         0  Milano  2015-07-15 07:41:22   250
# 22        60  Milano  2015-07-15 08:41:55   250
# 23       100  Milano  2015-07-15 09:39:10   250
# 24        90  Milano  2015-07-24 11:40:49   250
# 25        70  Milano  2015-07-24 12:41:32   250
# 26        80  Milano  2015-07-24 13:40:45   250
# 27       130  Milano  2015-07-24 14:39:38   250
# 28       130  Milano  2015-07-24 15:39:48   250
# 29         0  Milano  2015-07-24 16:39:36   250
# ..       ...     ...                  ...   ...
# 36       140  Milano  2015-07-24 23:40:26   250
# 37        30  Milano  2015-07-25 00:39:16   250
# 38       350  Milano  2015-07-25 01:41:16   250
# 39        10  Milano  2015-07-25 02:40:48   250
# 40         0  Milano  2015-07-25 03:40:06   250
# 41       110  Milano  2015-07-25 04:40:26   250
# 42        10  Milano  2015-07-25 05:40:51   250
# 43         0  Milano  2015-07-25 06:41:00   250
# 44       200  Milano  2015-07-25 07:39:43   250
# 45         0  Milano  2015-07-25 08:40:24   250
# 46         0  Milano  2015-07-25 09:39:47   250
# 47        70  Milano  2015-07-25 10:40:33   250
# 48       140  Milano  2015-06-27 09:42:05   250
# 49       160  Milano  2015-06-27 10:37:23   250
# 50       210  Milano  2015-06-27 11:56:55   250
# 51       220  Milano  2015-06-27 12:53:36   250
# 52       210  Milano  2015-06-27 13:54:14   250
# 53       230  Milano  2015-06-27 14:55:00   250
# 54       250  Milano  2015-06-27 16:54:53   250
# 55       220  Milano  2015-06-27 17:55:37   250
# 56       270  Milano  2015-06-27 18:58:11   250
# 57       310  Milano  2015-06-27 19:58:49   250
# 58       200  Milano  2015-06-27 22:52:33   250
# 59       210  Milano  2015-06-27 23:57:16   250
# 60       120  Milano  2015-06-28 00:57:38   250
# 61        90  Milano  2015-06-28 03:00:26   250
# 62        50  Milano  2015-06-28 03:54:42   250
# 63        40  Milano  2015-06-28 04:53:56   250
# 64        40  Milano  2015-06-28 05:57:54   250
# 65         0  Milano  2015-06-28 06:52:57   250
#
# [66 rows x 10 columns]

# %%
plt.plot(milano['wind_deg'],milano['wind_speed'],'ro')

# %% [markdown]
# 在子图中，同时比较风向与湿度和风力的关系

# %%
axes1 = plt.subplot(121)

axes1.scatter(milano['wind_deg'],milano['humidity'])

axes2 = plt.subplot(122)

axes2.scatter(milano['wind_deg'],milano['wind_speed'])

# %% [markdown]
# 可以看到散点图显示效果不好

# %% [markdown]
# 由于风向是360度，我们可以考虑使用玫瑰图（极坐标条形图)

# %% [markdown]
# 首先自定义一个画图函数show_rose

# %%
def show_rose(values,title):
    # 玫瑰图花瓣的个数8，每瓣45度
    n = 8
    angle = np.arange(0,2*np.pi,2*np.pi/n)
    
    # 绘制的数据values
    radius = np.array(values)
    # axis代表轴：（x，y）
    # axes代表整个画面
    plt.axes([0,0,1,1],polar = True)
    
    color = np.random.random(size = 24).reshape((8,3))
    
    plt.bar(angle,radius, color = color)
    
    plt.title(title,loc = 'left')

# %% [markdown]
# 用numpy创建一个直方图，将360度划分为8个面元，将数据分类到这8个面元中

# %%
n = np.array([1,1,1.8,2,3,3,3,4])
np.histogram(n,4,[1,4])
# Out:
# (array([2, 2, 3, 1]), array([ 1.  ,  1.75,  2.5 ,  3.25,  4.  ]))

# %%
degree = milano['wind_deg']

d,b = np.histogram(degree,8,[0,360])

# %%
show_rose(d, 'milano')

# %% [markdown]
# 计算米兰各个方向上的风速

# %%
milano
# Out:
#      temp  humidity  pressure             description          dt  wind_speed  \
# 0   28.57        54      1016            Sky is Clear  1436863175         2.1
# 1   29.74        48      1016            Sky is Clear  1436866758         2.6
# 2   31.12        48      1016            Sky is Clear  1436870509         2.6
# 3   32.16        45      1015            Sky is Clear  1436874098         2.1
# 4   33.59        43      1015            Sky is Clear  1436877644         3.1
# 5   34.21        36      1014            Sky is Clear  1436881329         2.1
# 6   34.41        38      1014            Sky is Clear  1436884928         2.1
# 7   34.81        38      1014            Sky is Clear  1436888512         3.1
# 8   34.09        38      1013            Sky is Clear  1436892131         2.6
# 9   33.20        35      1014            Sky is Clear  1436895722         4.1
# 10  31.55        48      1013            Sky is Clear  1436899336         2.1
# 11  28.33        61      1014            Sky is Clear  1436902942         2.1
# 12  27.58        51      1014            Sky is Clear  1436906530         2.1
# 13  26.29        61      1015        scattered clouds  1436910148         0.5
# 14  25.32        61      1015              few clouds  1436913738         1.0
# 15  24.23        65      1015            Sky is Clear  1436917310         1.5
# 16  24.29        65      1015            Sky is Clear  1436920930         1.5
# 17  23.75        65      1016            Sky is Clear  1436924426         2.6
# 18  23.64        69      1015            Sky is Clear  1436928077         1.0
# 19  23.70        69      1015            Sky is Clear  1436931717         1.0
# 20  22.22        73      1016            Sky is Clear  1436935297         1.5
# 21  23.45        65      1016              few clouds  1436938882         1.0
# 22  25.67        73      1016              few clouds  1436942515         1.5
# 23  28.68        54      1017              few clouds  1436945950         3.1
# 24  29.50        48      1011              few clouds  1437730849         3.6
# 25  30.81        45      1011              few clouds  1437734492         2.6
# 26  31.91        45      1010   proximity shower rain  1437738045         3.1
# 27  32.72        40      1009   proximity shower rain  1437741578         3.6
# 28  33.44        38      1009            Sky is Clear  1437745188         3.6
# 29  34.38        38      1008            Sky is Clear  1437748776         2.6
# ..    ...       ...       ...                     ...         ...         ...
# 36  23.47        54      1008           moderate rain  1437774026         2.6
# 37  22.53        53      1009           moderate rain  1437777556         3.6
# 38  22.50        61      1008           moderate rain  1437781276         2.1
# 39  22.07        93      1009    heavy intensity rain  1437784848         4.6
# ..       ...     ...                  ...   ...
# 36       140  Milano  2015-07-24 23:40:26   250
# 37        30  Milano  2015-07-25 00:39:16   250
# 38       350  Milano  2015-07-25 01:41:16   250
# 39        10  Milano  2015-07-25 02:40:48   250
# 40         0  Milano  2015-07-25 03:40:06   250
# 41       110  Milano  2015-07-25 04:40:26   250
# 42        10  Milano  2015-07-25 05:40:51   250
# 43         0  Milano  2015-07-25 06:41:00   250
# 44       200  Milano  2015-07-25 07:39:43   250
# 45         0  Milano  2015-07-25 08:40:24   250
# 46         0  Milano  2015-07-25 09:39:47   250
# 47        70  Milano  2015-07-25 10:40:33   250
# 48       140  Milano  2015-06-27 09:42:05   250
# 49       160  Milano  2015-06-27 10:37:23   250
# 50       210  Milano  2015-06-27 11:56:55   250
# 51       220  Milano  2015-06-27 12:53:36   250
# 52       210  Milano  2015-06-27 13:54:14   250
# 53       230  Milano  2015-06-27 14:55:00   250
# 54       250  Milano  2015-06-27 16:54:53   250
# 55       220  Milano  2015-06-27 17:55:37   250
# 56       270  Milano  2015-06-27 18:58:11   250
# 57       310  Milano  2015-06-27 19:58:49   250
# 58       200  Milano  2015-06-27 22:52:33   250
# 59       210  Milano  2015-06-27 23:57:16   250
# 60       120  Milano  2015-06-28 00:57:38   250
# 61        90  Milano  2015-06-28 03:00:26   250
# 62        50  Milano  2015-06-28 03:54:42   250
# 63        40  Milano  2015-06-28 04:53:56   250
# 64        40  Milano  2015-06-28 05:57:54   250
# 65         0  Milano  2015-06-28 06:52:57   250
#
# [66 rows x 10 columns]

# %%
b_list = list(b)
b_list
# Out:
# [0.0, 45.0, 90.0, 135.0, 180.0, 225.0, 270.0, 315.0, 360.0]

# %% [markdown]
# 将各个方向的风速保存在列表中

# %%
per_wind_speed = []
i = 1
while i < len(b_list):
    per_b_mean = milano[(milano['wind_deg'] >= b_list[i - 1]) & (milano['wind_deg'] < b_list[i])]['wind_speed'].mean()
    per_wind_speed.append(per_b_mean)
    print(per_b_mean)
    i += 1

per_wind_speed
# Out:
# 1.81428571429
# 2.22222222222
# 2.85555555556
# 2.58333333333
# 2.32857142857
# 2.26666666667
# 2.05
# 2.1
# [1.8142857142857143,
#  2.2222222222222223,
#  2.8555555555555561,
#  2.583333333333333,
#  2.3285714285714287,
#  2.2666666666666671,
#  2.0499999999999998,
#  2.1000000000000001]

# %% [markdown]
# 画出各个方向的风速

# %%
wind_speed_nd = np.array(per_wind_speed)
wind_speed_nd
# Out:
# array([ 1.81428571,  2.22222222,  2.85555556,  2.58333333,  2.32857143,
#         2.26666667,  2.05      ,  2.1       ])

# %%
show_rose(wind_speed_nd, "speed")

# %% [markdown]
# 将上面步骤写成函数

# %%
def RoseWind_Speed(city):
   degs = np.arange(45,361,45)
   tmp =  []
   for deg in degs:
      tmp.append(city[(city['wind_deg']>(deg-46)) & (city['wind_deg']<deg)]['wind_speed'].mean())
   return np.array(tmp)

# %%
show_rose(RoseWind_Speed(torino), 'Torino')
